# %% [markdown]
# [Basic Data Exploration](#basic-explor)
#
# [Bivariate analysis](#bivar)

# %% [markdown]
# ## Course Structure
#
# 1. Module 0 - Native Data Types in Python
# 2. Module 1 - Intro to Pandas library & Basis Dataframe attributes
# 3. Module 2 - Common Data manipulation tasks using Pandas
# 4. Module 3 - Loops and Functions
# 5. Module 4 - Visualization
# 6. Module 5 - Other miscellaneous topics

# %% [markdown]
# # Basic data types

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
#list, dictionaries , tuples


mylist= [20,30,50,40,50,60,70,80]
mylist[:7]
# Out:
# [20, 30, 50, 40, 50, 60, 70]

# %%
x = [1,"b",3]

# %%
x[1]
# Out:
# 'b'

# %%
dict={"palak":"student","you":"hello",5:"number"}
dict["palak"]
dict[5]
dict.keys()
dict.values()
# Out:
# 'student'
# 'number'
# dict_keys(['palak', 'you', 5])
# dict_values(['student', 'hello', 'number'])

# %%
students={"s_1":["ibm"], "s_2" :["infy","wipro" , "google"]}
students["s_1"]
students["s_2"]
students["s_2"][1]
# Out:
# ['ibm']
# ['infy', 'wipro', 'google']
# 'wipro'

# %%
student_dict = {"s_1":["IBM","TCS"],"s_2" :["HP"], "s_3":["INFOSYS","WIPRO"]}

# %%
[val for k,val in student_dict.items()]
# Out:
# [['IBM', 'TCS'], ['HP'], ['INFOSYS', 'WIPRO']]

# %%
x = ["abe",1,"c"]

# %%
dist_ex = {"S1":["HCL","TCS"],"S2":["Benz"]}

# %%
for k,v in dist_ex.items():
    if k == "S1":
        print(k)
# Out:
# S1

# %%
x.append("h")

# %% [markdown]
# #This is to test python

# %%
tup_ex = (1,2,3,1)
mylist=[1,2,3,4,5]
mylist.append(7) #adding elements
mylist
tup_ex. #press tab , you wont see any append option that shows tuple are immutable
# Out:
#   File "<ipython-input-13-45aebc31be83>", line 5
#     tup_ex. #press tab , you wont see any append option that shows tuple are immutable
#                                                                                       ^
# SyntaxError: invalid syntax

# %%
# !pip install pandas
# Out:
# ...
# You are using pip version 9.0.1, however version 20.2.2 is available.
# You should consider upgrading via the 'python -m pip install --upgrade pip' command.

# %%
list_ex = [1,2,3]
dist_ex = {"Age":25,"Weight":70}

tup_ex = (1,2,3,1)

# %%
from pandas import read_csv

# %%
# read the data
import pandas as pd
#import numpy as np
df = pd.read_csv("Uber Drives 2016.csv") #df is data frame ,df is a basic data structure we have in pandas which representsthe data in the form of rows and colomns

# %%
# NaN is negligible . its not none

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %% [markdown]
# # Key Modules
#
# 1. Basic Dataframe operations
# 2. Common data manipulation tasks
# 3. Loops and Functions

# %% [markdown]
# ## Basic dataframe operations

# %%
hasattr(df,"head")
callable(getattr(df,"head"))
# Out:
# True
# True

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# START_DATE*     object
# END_DATE*       object
# CATEGORY*       object
# START*          object
# STOP*           object
# MILES*         float64
# PURPOSE*        object
# dtype: object

# %%
df.head()  #put the mouse cursor in the brackets and press shift tabs , youll see the details
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %%
df.shape #to know how many rows and columns
# Out:
# (1156, 7)

# %%
df.tail()
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 1151  Unknown Location      3.9  Temporary Site
# 1152  Unknown Location     16.2         Meeting
# 1153           Gampaha      6.4  Temporary Site
# 1154         Ilukwatta     48.2  Temporary Site
# 1155               NaN  12204.7             NaN

# %% [markdown]
# ### Changing data types

# %%
temp = pd.DataFrame({"A":["1","2","3"],"B":[11,12,13],"C": ["12-06-2012","13-06-2015","15-06-2017"]})

# %%
temp
# Out:
#    A   B           C
# 0  1  11  12-06-2012
# 1  2  12  13-06-2015
# 2  3  13  15-06-2017

# %%
temp.dtypes
# Out:
# A    object
# B     int64
# C    object
# dtype: object

# %%
pd.to_datetime("2016-11-02") 
pd.to_datetime("2016-jun-02")
# Out:
# Timestamp('2016-11-02 00:00:00')
# Timestamp('2016-06-02 00:00:00')

# %%
pd.to_datetime(["2016-11-02","2016-04-15"])
# Out:
# DatetimeIndex(['2016-11-02', '2016-04-15'], dtype='datetime64[ns]', freq=None)

# %%
temp["C"] = pd.to_datetime(temp["C"])

# %%
temp["A"] = pd.to_numeric(temp["A"])

# %%
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp["C"]=pd.to_datetime(temp["C"]) #THIS IS HOW YOU ACCESSS A COLUMN FROM A DATAFRAME .temp is the data frame , i want to access C . = refers to i want to do some thing with it. like convert the date time of this column!! 
temp #when you are doing this modification , the original dataframe will get changed.if you dont want to change , then assign to another data frame
temp.dtypes #in pamdas there are some operations that will chang the data frame some will not CONFUSING.
#if you're adding a column  to another , it will change data frame.
pd.to_datetime(["2016-sep-11", "abc"],errors="coerce") #it will understand that you want to convert data where it cant it will say NaT
# Out:
#    A   B          C
# 0  1  11 2012-12-06
# 1  2  12 2015-06-13
# 2  3  13 2017-06-15
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object
# DatetimeIndex(['2016-09-11', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
temp["A"] = temp["A"].astype(str)

# %%
temp.dtypes
# Out:
# A            object
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
temp["A"] = pd.to_numeric(temp["A"]) #another method

# %%
temp.dtypes
# Out:
# A             int64
# B             int64
# C    datetime64[ns]
# dtype: object

# %%
# convert data to datetime format
pd.to_datetime(df["START_DATE*"],format='%m/%d/%Y %H:%M')
# Available time formats: https://docs.python.org/3/library/datetime.html#strftime-and-strptime-behavior
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\tools\datetimes.py in _convert_listlike(arg, box, format, name, tz)
#     443             try:
# --> 444                 values, tz = tslib.datetime_to_datetime64(arg)
#     445                 return DatetimeIndex._simple_new(values, name=name, tz=tz)
#
# pandas/_libs/tslib.pyx in pandas._libs.tslib.datetime_to_datetime64 (pandas\_libs\tslib.c:33275)()
#
# TypeError: Unrecognized value type: <class 'str'>
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-39-db1c3c11ef14> in <module>()
#       1 # convert data to datetime format
# ----> 2 pd.to_datetime(df["START_DATE*"],format='%m/%d/%Y %H:%M')
# ...

# %% [markdown]
# ### Dataset summarization methods

# %%
df.describe(include="all")

# %%
df.info()

# %%
# count of unique start locations
df["START*"].value_counts()

# %%
# count of unique start locations
df["START*"].value_counts().head()
# Out:
# Cary                201
# Unknown Location    148
# Morrisville          85
# Whitebridge          68
# Islamabad            57
# Name: START*, dtype: int64

# %% [markdown]
# ## Common data manipulation tasks

# %% [markdown]
# 5 verbs of data manipulation
#
# 1. Selecting/Indexing
# 2. Filtering
# 3. Sorting
# 4. Mutating/ Conditionally adding columns
# 5. Groupby/Summarize

# %% [markdown]
# ### Select/Indexing

# %%
# 2 methods
#iloc - number based (not used these days)
#loc -- label based

# %%
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.iloc[0:5, 0:4] #0 : 5 is row ND 0:4 IS COLUMN , WHERE LAST ONE IS NOT INCLUDED
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce

# %%
## Positional Indexing
df.iloc[0:4,[0,2]]
# Out:
#       START_DATE* CATEGORY*
# 0  1/1/2016 21:11  Business
# 1   1/2/2016 1:25  Business
# 2  1/2/2016 20:25  Business
# 3  1/5/2016 17:31  Business

# %%
df.iloc[:,0:4] #i want all the rows but only 4 columns
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
df.iloc[:,:-1]
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %%
palak=df.iloc[:,:-1]
print(df.shape)
palak.shape #if i dont wanna change my original framework
# Out:
# (1156, 7)
# (1156, 6)

# %%
df.iloc[0:4,0:3]
# Out:
#       START_DATE*       END_DATE* CATEGORY*
# 0  1/1/2016 21:11  1/1/2016 21:17  Business
# 1   1/2/2016 1:25   1/2/2016 1:37  Business
# 2  1/2/2016 20:25  1/2/2016 20:38  Business
# 3  1/5/2016 17:31  1/5/2016 17:45  Business

# %%
# label based indexing
df.loc[:,["START_DATE*","CATEGORY*"]].head()
# Out:
#       START_DATE* CATEGORY*
# 0  1/1/2016 21:11  Business
# 1   1/2/2016 1:25  Business
# 2  1/2/2016 20:25  Business
# 3  1/5/2016 17:31  Business
# 4  1/6/2016 14:42  Business

# %%
# label based indexing
df.loc[:,"START*"]
# Out:
# 0             Fort Pierce
# 1             Fort Pierce
# 2             Fort Pierce
# 3             Fort Pierce
# 4             Fort Pierce
# 5         West Palm Beach
# 6         West Palm Beach
# 7                    Cary
# 8                    Cary
# 9                 Jamaica
# 10               New York
# 11               Elmhurst
# 12                Midtown
# 13            East Harlem
# 14      Flatiron District
# 15                Midtown
# 16           Midtown East
# 17                Midtown
# 18          Hudson Square
# 19        Lower Manhattan
# 20          Hudson Square
# 21         Hell's Kitchen
# 22               New York
# 23               Downtown
# 24                Gulfton
# 25                Houston
# 26             Eagan Park
# 27            Morrisville
# 28                   Cary
# 29                 Durham
#               ...
# 1126     Unknown Location
# 1127              Kar?chi
# 1128              Kar?chi
# 1129     Unknown Location
# 1130              Kar?chi
# ...

# %%
# label based indexing
df.loc[:,["START*","STOP*"]]
# Out:
#                  START*             STOP*
# 0           Fort Pierce       Fort Pierce
# 1           Fort Pierce       Fort Pierce
# 2           Fort Pierce       Fort Pierce
# 3           Fort Pierce       Fort Pierce
# 4           Fort Pierce   West Palm Beach
# 5       West Palm Beach   West Palm Beach
# 6       West Palm Beach        Palm Beach
# 7                  Cary              Cary
# 8                  Cary       Morrisville
# 9               Jamaica          New York
# 10             New York            Queens
# 11             Elmhurst          New York
# 12              Midtown       East Harlem
# 13          East Harlem             NoMad
# 14    Flatiron District           Midtown
# 15              Midtown      Midtown East
# 16         Midtown East           Midtown
# 17              Midtown     Hudson Square
# 18        Hudson Square   Lower Manhattan
# 19      Lower Manhattan     Hudson Square
# 20        Hudson Square    Hell's Kitchen
# ...

# %%
df[["START*","STOP*"]] #ANOTHER METHOD
# Out:
#                  START*             STOP*
# 0           Fort Pierce       Fort Pierce
# 1           Fort Pierce       Fort Pierce
# 2           Fort Pierce       Fort Pierce
# 3           Fort Pierce       Fort Pierce
# 4           Fort Pierce   West Palm Beach
# 5       West Palm Beach   West Palm Beach
# 6       West Palm Beach        Palm Beach
# 7                  Cary              Cary
# 8                  Cary       Morrisville
# 9               Jamaica          New York
# 10             New York            Queens
# 11             Elmhurst          New York
# 12              Midtown       East Harlem
# 13          East Harlem             NoMad
# 14    Flatiron District           Midtown
# 15              Midtown      Midtown East
# 16         Midtown East           Midtown
# 17              Midtown     Hudson Square
# 18        Hudson Square   Lower Manhattan
# 19      Lower Manhattan     Hudson Square
# 20        Hudson Square    Hell's Kitchen
# ...

# %%
# label based indexing
df.loc[:,["START*","STOP*"]]
abc= df.loc[:,"START*"]
type(abc)
# Out:
#                  START*             STOP*
# 0           Fort Pierce       Fort Pierce
# 1           Fort Pierce       Fort Pierce
# 2           Fort Pierce       Fort Pierce
# 3           Fort Pierce       Fort Pierce
# 4           Fort Pierce   West Palm Beach
# 5       West Palm Beach   West Palm Beach
# 6       West Palm Beach        Palm Beach
# 7                  Cary              Cary
# 8                  Cary       Morrisville
# 9               Jamaica          New York
# 10             New York            Queens
# 11             Elmhurst          New York
# 12              Midtown       East Harlem
# 13          East Harlem             NoMad
# 14    Flatiron District           Midtown
# 15              Midtown      Midtown East
# 16         Midtown East           Midtown
# 17              Midtown     Hudson Square
# 18        Hudson Square   Lower Manhattan
# 19      Lower Manhattan     Hudson Square
# 20        Hudson Square    Hell's Kitchen
# ...

# %% [markdown]
# ### In Class assignment
#
# Extract first 5 rows and columns START_DATE* and MILES*

# %%
df.loc[0:4,["START_DATE*","MILES*"]]
# Out:
#       START_DATE*  MILES*
# 0  1/1/2016 21:11     5.1
# 1   1/2/2016 1:25     5.0
# 2  1/2/2016 20:25     4.8
# 3  1/5/2016 17:31     4.7
# 4  1/6/2016 14:42    63.7

# %% [markdown]
# ### Filtering

# %%
df[df["MILES*"] > 10]
df2 = df[df["MILES*"] > 10]
df2
# Out:
#            START_DATE*         END_DATE* CATEGORY*               START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business          Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business              Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business             New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business             New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business             Downtown
# 24     1/13/2016 15:00   1/13/2016 15:28  Business              Gulfton
# 25     1/14/2016 16:29   1/14/2016 17:05  Business              Houston
# 28     1/15/2016 11:43   1/15/2016 12:03  Business                 Cary
# 29     1/15/2016 13:26   1/15/2016 13:44  Business               Durham
# 34     1/20/2016 10:36   1/20/2016 11:11  Business                 Cary
# 35     1/20/2016 11:48   1/20/2016 12:19  Business  Fayetteville Street
# 36     1/20/2016 13:25   1/20/2016 14:19  Business              Raleigh
# ...

# %%
df3 = df2.loc[0:3]

# %%
# find out all rides greater than 10 miles
df.loc[df["MILES*"] > 10].head()
# Out:
#         START_DATE*        END_DATE* CATEGORY*       START*            STOP*  \
# 4    1/6/2016 14:42   1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
# 9   1/10/2016 12:17  1/10/2016 12:44  Business      Jamaica         New York
# 10  1/10/2016 15:08  1/10/2016 15:51  Business     New York           Queens
# 22  1/12/2016 16:02  1/12/2016 17:00  Business     New York    Queens County
# 23  1/13/2016 13:54  1/13/2016 14:07  Business     Downtown          Gulfton
#
#     MILES*        PURPOSE*
# 4     63.7  Customer Visit
# 9     16.5  Customer Visit
# 10    10.8         Meeting
# 22    15.1         Meeting
# 23    11.2         Meeting

# %%
# Find out all rides from New York
df.loc[df["START*"]=="New York",["MILES*"]].head()
# Out:
#      MILES*
# 10     10.8
# 22     15.1
# 106    13.0
# 423    16.3

# %%
# Find out all rides from Cary & NewYork         
my_rides=df[df["START*"].isin(["Cary","NewYork"])]
my_rides.head(n=10)
# Out:
#         START_DATE*        END_DATE* CATEGORY* START*        STOP*  MILES*  \
# 7    1/7/2016 13:27   1/7/2016 13:33  Business   Cary         Cary     0.8
# 8    1/10/2016 8:05   1/10/2016 8:25  Business   Cary  Morrisville     8.3
# 28  1/15/2016 11:43  1/15/2016 12:03  Business   Cary       Durham    10.4
# 30  1/18/2016 14:55  1/18/2016 15:06  Business   Cary         Cary     4.8
# 34  1/20/2016 10:36  1/20/2016 11:11  Business   Cary      Raleigh    17.1
# 37  1/21/2016 14:25  1/21/2016 14:29  Business   Cary         Cary     1.6
# 38  1/21/2016 14:43  1/21/2016 14:51  Business   Cary         Cary     2.4
# 39  1/21/2016 16:01  1/21/2016 16:06  Business   Cary         Cary     1.0
# 43  1/26/2016 17:17  1/26/2016 17:22  Business   Cary         Cary     1.4
# 44  1/26/2016 17:27  1/26/2016 17:29  Business   Cary         Cary     0.5
#
#            PURPOSE*
# 7           Meeting
# 8           Meeting
# 28   Meal/Entertain
# 30   Meal/Entertain
# 34          Meeting
# ...

# %%
# Find out all rides from Cary & Morrisville          
my_rides=df[df["START*"].isin(["Cary","Morrisville"])]
my_rides.iloc[0:5,:]
# Out:
#         START_DATE*        END_DATE* CATEGORY*       START*        STOP*  \
# 7    1/7/2016 13:27   1/7/2016 13:33  Business         Cary         Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business         Cary  Morrisville
# 27   1/15/2016 0:41   1/15/2016 1:01  Business  Morrisville         Cary
# 28  1/15/2016 11:43  1/15/2016 12:03  Business         Cary       Durham
# 30  1/18/2016 14:55  1/18/2016 15:06  Business         Cary         Cary
#
#     MILES*         PURPOSE*
# 7      0.8          Meeting
# 8      8.3          Meeting
# 27     8.0  Errand/Supplies
# 28    10.4   Meal/Entertain
# 30     4.8   Meal/Entertain

# %%
# Find out all rides to Cary & Morrisville          
df.loc[df["START*"].isin(["Cary","Morrisville"])].shape
# Out:
# (286, 7)

# %%
df.loc[~df["START*"].isin(["Cary","Morrisville"])].shape
# Out:
# (870, 7)

# %% [markdown]
# #### In class assignment
#
# 1. Find all trips with distance > 10 miles and originating from Cary and Morris.
#
# 2. Extract top 3 rows from the filtered dataset

# %%
df3 = df.loc[(df["MILES*"] > 10) & (df["START*"].isin(["Cary", "Morrisville"]))]
df3.reset_index() #to change the index
df3
# Out:
#     index       START_DATE*         END_DATE* CATEGORY*       START*  \
# 0      28   1/15/2016 11:43   1/15/2016 12:03  Business         Cary
# 1      34   1/20/2016 10:36   1/20/2016 11:11  Business         Cary
# 2      46   1/27/2016 10:19   1/27/2016 10:48  Business         Cary
# 3      50   1/28/2016 12:28   1/28/2016 13:00  Business         Cary
# 4      55   1/29/2016 11:43   1/29/2016 12:03  Business         Cary
# 5      61    2/1/2016 10:35    2/1/2016 11:15  Business         Cary
# 6      74    2/5/2016 11:47    2/5/2016 12:07  Business         Cary
# 7      76    2/6/2016 16:20    2/6/2016 16:53  Business         Cary
# 8      91   2/11/2016 16:28   2/11/2016 17:10  Business         Cary
# 9      97   2/12/2016 11:14   2/12/2016 11:35  Business  Morrisville
# 10    100   2/12/2016 15:33   2/12/2016 16:06  Business  Morrisville
# 11    164   2/26/2016 11:35   2/26/2016 11:59  Business         Cary
# 12    185    3/4/2016 11:46    3/4/2016 12:06  Business         Cary
# ...

# %%
df3 = df.loc[(df["MILES*"] > 10) & (df["START*"].isin(["Cary", "Morrisville"]))]
df3.reset_index() #here you can change the data frame to any thing else
df3
df4
# Out:
#     index       START_DATE*         END_DATE* CATEGORY*       START*  \
# 0      28   1/15/2016 11:43   1/15/2016 12:03  Business         Cary
# 1      34   1/20/2016 10:36   1/20/2016 11:11  Business         Cary
# 2      46   1/27/2016 10:19   1/27/2016 10:48  Business         Cary
# 3      50   1/28/2016 12:28   1/28/2016 13:00  Business         Cary
# 4      55   1/29/2016 11:43   1/29/2016 12:03  Business         Cary
# 5      61    2/1/2016 10:35    2/1/2016 11:15  Business         Cary
# 6      74    2/5/2016 11:47    2/5/2016 12:07  Business         Cary
# 7      76    2/6/2016 16:20    2/6/2016 16:53  Business         Cary
# 8      91   2/11/2016 16:28   2/11/2016 17:10  Business         Cary
# 9      97   2/12/2016 11:14   2/12/2016 11:35  Business  Morrisville
# 10    100   2/12/2016 15:33   2/12/2016 16:06  Business  Morrisville
# 11    164   2/26/2016 11:35   2/26/2016 11:59  Business         Cary
# 12    185    3/4/2016 11:46    3/4/2016 12:06  Business         Cary
# ...

# %%
df3 = df.loc[(df["MILES*"] > 10) & (df["START*"].isin(["Cary", "Morrisville"]))]
df3.reset_index(inplace= True) #if i want df3 to be my final answer then inplace, that means if the index is mixed up it will add a new column called index in the form of 0,1.2,3 and a seperate column for the old index
df3

# %% [markdown]
# ### Sorting

# %%
df.sort_values(by=["MILES*"],ascending=False).head(20)
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1155            Totals               NaN       NaN               NaN
# 269    3/25/2016 16:52   3/25/2016 22:22  Business             Latta
# 270    3/25/2016 22:54    3/26/2016 1:39  Business      Jacksonville
# 881   10/30/2016 15:22  10/30/2016 18:23  Business         Asheville
# 776    9/27/2016 21:01    9/28/2016 2:37  Business  Unknown Location
# 546    7/14/2016 16:39   7/14/2016 20:05  Business       Morrisville
# 559    7/17/2016 12:20   7/17/2016 15:25  Personal             Boone
# 297     4/2/2016 19:38    4/2/2016 22:36  Business      Jacksonville
# 299      4/3/2016 2:00     4/3/2016 4:16  Business          Florence
# 727    8/27/2016 16:15   8/27/2016 19:13  Business  Unknown Location
# 298     4/2/2016 23:11     4/3/2016 1:34  Business         Ridgeland
# 268    3/25/2016 13:24   3/25/2016 16:22  Business              Cary
# 232    3/17/2016 12:52   3/17/2016 15:11  Business            Austin
# ...

# %%
df.sort_values(by=["START*", "MILES*"],ascending=[True,False]).head(5)
# Out:
#           START_DATE*         END_DATE* CATEGORY*  START*        STOP*  \
# 906   11/4/2016 21:04   11/4/2016 21:20  Business   Agnew         Cory
# 911   11/6/2016 10:50   11/6/2016 11:04  Business   Agnew  Renaissance
# 908    11/5/2016 8:34    11/5/2016 8:43  Business   Agnew  Renaissance
# 910   11/5/2016 19:20   11/5/2016 19:28  Business   Agnew        Agnew
# 879  10/30/2016 12:58  10/30/2016 13:18  Business  Almond  Bryson City
#
#      MILES* PURPOSE*
# 906     4.3      NaN
# 911     2.4      NaN
# 908     2.2      NaN
# 910     2.2      NaN
# 879    15.2      NaN

# %% [markdown]
# ### Conditionally adding columns

# %%
import numpy as np
df["miles_cat"] = np.where(df["MILES*"] > 5,"Long Trip","Short Trip") #np.where means that if miles is greater then 5 , mark it as long trip else short trip

# %%
df.head(30)
df["my_year"]=np.array(2000,2010)
df
# Out:
#         START_DATE*        END_DATE* CATEGORY*             START*  \
# 0    1/1/2016 21:11   1/1/2016 21:17  Business        Fort Pierce
# 1     1/2/2016 1:25    1/2/2016 1:37  Business        Fort Pierce
# 2    1/2/2016 20:25   1/2/2016 20:38  Business        Fort Pierce
# 3    1/5/2016 17:31   1/5/2016 17:45  Business        Fort Pierce
# 4    1/6/2016 14:42   1/6/2016 15:49  Business        Fort Pierce
# 5    1/6/2016 17:15   1/6/2016 17:19  Business    West Palm Beach
# 6    1/6/2016 17:30   1/6/2016 17:35  Business    West Palm Beach
# 7    1/7/2016 13:27   1/7/2016 13:33  Business               Cary
# 8    1/10/2016 8:05   1/10/2016 8:25  Business               Cary
# 9   1/10/2016 12:17  1/10/2016 12:44  Business            Jamaica
# 10  1/10/2016 15:08  1/10/2016 15:51  Business           New York
# 11  1/10/2016 18:18  1/10/2016 18:53  Business           Elmhurst
# 12  1/10/2016 19:12  1/10/2016 19:32  Business            Midtown
# ...

# %%
df["miles_cat"].value_counts()
# Out:
# Long Trip     654
# Short Trip    502
# Name: miles_cat, dtype: int64

# %%
df.loc[df["MILES*"] > 5].shape
# Out:
# (654, 8)

# %% [markdown]
# ## In class Assignment
#
# Create a new column with the following condition:
#
# a) > 10 - Long Trip
#
# b) 5 - 10  - Medium
#
# c) < 5 - Short Trip

# %%
import numpy as np
df["new"] = np.where(df["MILES*"] > 10 ,"Long Trip","medium and Short Trip")
df["new"] = np.where(df["MILES*"] < 5 ,"Short Trip ","medium ")
df
# Out:
#            START_DATE*         END_DATE* CATEGORY*             START*  \
# 0       1/1/2016 21:11    1/1/2016 21:17  Business        Fort Pierce
# 1        1/2/2016 1:25     1/2/2016 1:37  Business        Fort Pierce
# 2       1/2/2016 20:25    1/2/2016 20:38  Business        Fort Pierce
# 3       1/5/2016 17:31    1/5/2016 17:45  Business        Fort Pierce
# 4       1/6/2016 14:42    1/6/2016 15:49  Business        Fort Pierce
# 5       1/6/2016 17:15    1/6/2016 17:19  Business    West Palm Beach
# 6       1/6/2016 17:30    1/6/2016 17:35  Business    West Palm Beach
# 7       1/7/2016 13:27    1/7/2016 13:33  Business               Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business               Cary
# 9      1/10/2016 12:17   1/10/2016 12:44  Business            Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business           New York
# 11     1/10/2016 18:18   1/10/2016 18:53  Business           Elmhurst
# ...

# %% [markdown]
# ### Groupby Summarize

# %%
grouping - S A C
SPLIT
APPLY 
COMBINE
# Out:
#   File "<ipython-input-72-8f1907d8f462>", line 1
#     grouping - S A C
#                  ^
# SyntaxError: invalid syntax

# %%
# for each start loc find the mean distance travelled
df.groupby("START*")["MILES*"].agg("mean") #aggregation
# Out:
# START*
# Agnew                           2.775000
# Almond                         15.200000
# Apex                            5.341176
# Arabi                          17.000000
# Arlington                       4.900000
# Arlington Park at Amberly       1.300000
# Asheville                     143.850000
# Austin                        136.000000
# Banner Elk                     12.375000
# Bellevue                       12.900000
# Berkeley                       14.375000
# Boone                         102.000000
# Briar Meadow                    9.600000
# Bryson City                    20.820000
# Burtrose                        4.800000
# CBD                             3.850000
# Capitol One                     9.450000
# Cary                            8.911940
# Central                         1.950000
# Chalmette                       1.100000
# Chapel Hill                    20.150000
# Chessington                     3.350000
# College Avenue                  2.600000
# ...

# %%
df.groupby("START*")["MILES*"].mean() #second method since mean is a common operation
# Out:
# START*
# Agnew                           2.775000
# Almond                         15.200000
# Apex                            5.341176
# Arabi                          17.000000
# Arlington                       4.900000
# Arlington Park at Amberly       1.300000
# Asheville                     143.850000
# Austin                        136.000000
# Banner Elk                     12.375000
# Bellevue                       12.900000
# Berkeley                       14.375000
# Boone                         102.000000
# Briar Meadow                    9.600000
# Bryson City                    20.820000
# Burtrose                        4.800000
# CBD                             3.850000
# Capitol One                     9.450000
# Cary                            8.911940
# Central                         1.950000
# Chalmette                       1.100000
# Chapel Hill                    20.150000
# Chessington                     3.350000
# College Avenue                  2.600000
# ...

# %%
df.groupby("START*").agg("mean") #IF YOU HAVE JUST A SINGLE COLUMN WITH INTEGERS IT AUTOMATICALLY SHOWS THE RESULT OF INTEGER COLUMN
# Out:
#                                 MILES*
# START*
# Agnew                         2.775000
# Almond                       15.200000
# Apex                          5.341176
# Arabi                        17.000000
# Arlington                     4.900000
# Arlington Park at Amberly     1.300000
# Asheville                   143.850000
# Austin                      136.000000
# Banner Elk                   12.375000
# Bellevue                     12.900000
# Berkeley                     14.375000
# Boone                       102.000000
# Briar Meadow                  9.600000
# Bryson City                  20.820000
# Burtrose                      4.800000
# CBD                           3.850000
# Capitol One                   9.450000
# Cary                          8.911940
# Central                       1.950000
# Chalmette                     1.100000
# Chapel Hill                  20.150000
# Chessington                   3.350000
# College Avenue                2.600000
# ...

# %%
df.groupby(["START*","STOP*",]).agg(["mean","sum"]).head(20)
# Out:
#                                                          MILES*
#                                                            mean    sum
# START*                    STOP*
# Agnew                     Agnew                        2.200000    2.2
#                           Cory                         4.300000    4.3
#                           Renaissance                  2.300000    4.6
# Almond                    Bryson City                 15.200000   15.2
# Apex                      Apex                         2.150000    4.3
#                           Cary                         5.792308   75.3
#                           Eagle Rock                   2.200000    2.2
#                           Holly Springs                9.000000    9.0
# Arabi                     Metairie                    17.000000   17.0
# Arlington                 Washington                   4.900000    4.9
# Arlington Park at Amberly Lexington Park at Amberly    1.300000    1.3
# ...

# %%
# for each start loc find the mean & the total dist travelled
palak=df.groupby("START*").agg(["mean","sum"]).head()
palak.columns
# Out:
# MultiIndex(levels=[['MILES*'], ['mean', 'sum']],
#            labels=[[0, 0], [0, 1]])

# %% [markdown]
# ### In class assignment
#
# Find most recent & the earliest travelled date and mean distance traveled for each start city

# %%
df=df.iloc[:-1,:]
df.tail()
df["START_DATE*"]=pd.to_datetime(df["START_DATE*"])
df.dtypes
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 1150   12/31/2016 1:07   12/31/2016 1:14  Business           Kar?chi
# 1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
#
#                  STOP*  MILES*        PURPOSE*   miles_cat          new
# 1150           Kar?chi     0.7         Meeting  Short Trip  Short Trip
# 1151  Unknown Location     3.9  Temporary Site  Short Trip  Short Trip
# 1152  Unknown Location    16.2         Meeting   Long Trip      medium
# 1153           Gampaha     6.4  Temporary Site   Long Trip      medium
# 1154         Ilukwatta    48.2  Temporary Site   Long Trip      medium
# C:\Users\OM\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# ...

# %%
res = df.groupby("START*").agg({"MILES*":["mean"],"START_DATE*":["min","max"]})
res.reset_index(inplace=True)
#res
res.columns=["START_CITY","AVG_DIST","EARLIEST_TR","RECENT_TRIP"]
res.to_csv("palak.csv")

# %% [markdown]
# ## Loops and Function

# %%
# Basic for loop
res = []
temp = [1,2,3,4]
for i in temp:
    res.append(i*i)
res
# Out:
# [1, 4, 9, 16]

# %%
# List comprehension way

[x*x for x in temp]
# Out:
# [1, 4, 9, 16]

# %%
store_sales = pd.read_csv("store_sales.csv")

# %%
store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# 5       S_6  California   14   21   18   20   21    5    18   24    7   12
# 6       S_7     Arizona   11   22    5   14   16   24     8   15   18   14
# 7       S_8  California   15    8    5   15   12   21    17   19   13    6
# 8       S_9       Texas   15    7    6   20    5   18    19   15   19   17
# 9      S_10  California   14   23   20   11   12   13    19    6    5   22
# 10     S_11     Arizona   15   24    8   15   24   21     6   21   20   13
# ...

# %%
# find out avg sales for each month
# find out avg sales for each store

# %%
store_sales["Jan"].mean()
store_sales.apply("mean")
store_sales.apply("mean",axis=1) #mean for all column using APPLY FUNCTION  axis=1 is row , axis=0 is columnwise by default it is column
store_sales.select_dtypes(include=['int64','float64']).apply("mean") #for new versions of pandas, sometiomes it shows the column is string and shows an error
# Out:
# 14.46
# Jan     14.46
# Feb     15.09
# Mar     14.56
# Apr     14.57
# May     13.56
# Jun     13.80
# July    14.38
# Aug     15.81
# Sep     14.91
# Oct     14.10
# Nov     15.31
# Dec     13.57
# dtype: float64
# 0     14.833333
# 1     14.500000
# 2     15.083333
# 3     11.250000
# 4     13.250000
# 5     14.666667
# 6     15.333333
# 7     14.166667
# 8     14.000000
# 9     14.833333
# 10    16.333333
# 11    13.666667
# 12    15.666667
# 13    12.500000
# 14    14.416667
# 15    13.916667
# 16    15.750000
# 17    16.250000
# 18    13.416667
# 19    16.333333
# 20    12.416667
# 21    12.166667
# 22    15.166667
# 23    15.250000
# 24    13.750000
# 25    12.416667
# 26    14.916667
# 27    15.916667
# 28    12.166667
# 29    15.000000
#         ...
# 70    13.583333
# 71    12.583333
# 72    17.750000
# 73    15.750000
# 74    14.833333
# 75    15.250000
# 76    14.250000
# 77    17.583333
# 78    15.583333
# 79    16.666667
# 80    14.666667
# 81    12.583333
# ...

# %%
#to add new column
import numpy as np
def bonus_func(sales_col):
    elig_values=np.where(sales_col>10,"eligible","not eligible")
    return elig_values
store_sales["Jan_bonus"]=bonus_func(store_sales["Jan"])
store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# 5       S_6  California   14   21   18   20   21    5    18   24    7   12
# 6       S_7     Arizona   11   22    5   14   16   24     8   15   18   14
# 7       S_8  California   15    8    5   15   12   21    17   19   13    6
# 8       S_9       Texas   15    7    6   20    5   18    19   15   19   17
# 9      S_10  California   14   23   20   11   12   13    19    6    5   22
# 10     S_11     Arizona   15   24    8   15   24   21     6   21   20   13
# ...

# %%
import numpy as np
def bonus_func(sales_col):
    elig_values=np.where(sales_col>10,"eligible","not eligible")
    return elig_values
store_sales["Jan_bonus"]=bonus_func(store_sales["Jan"])
store_sales
# Out:
#    store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0       S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1       S_2  California   12   19   15   15   11   19     7   15   10   11
# 2       S_3  California   16   16   14   19   23    6    13   13   15   14
# 3       S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4       S_5       Texas   19    5   24    9    5   24    10    5   24   15
# 5       S_6  California   14   21   18   20   21    5    18   24    7   12
# 6       S_7     Arizona   11   22    5   14   16   24     8   15   18   14
# 7       S_8  California   15    8    5   15   12   21    17   19   13    6
# 8       S_9       Texas   15    7    6   20    5   18    19   15   19   17
# 9      S_10  California   14   23   20   11   12   13    19    6    5   22
# 10     S_11     Arizona   15   24    8   15   24   21     6   21   20   13
# ...

# %%
import numpy as np
def bonus_func(sales_col):
    elig_values=np.where(sales_col>10,"eligible","not eligible")
    return elig_values
#store_sales["Jan_bonus"]=bonus_func(store_sales["Jan"])
newdf = store_sales.select_dtypes(include=['int64','float64']).apply(bonus_func)
newdf
palak=pd.concat([store_sales,newdf],axis=1)
palak.shape
palak.tail()
# Out:
#              Jan           Feb           Mar           Apr           May  \
# 0   not eligible      eligible      eligible      eligible      eligible
# 1       eligible      eligible      eligible      eligible      eligible
# 2       eligible      eligible      eligible      eligible      eligible
# 3   not eligible      eligible      eligible  not eligible      eligible
# 4       eligible  not eligible      eligible  not eligible  not eligible
# 5       eligible      eligible      eligible      eligible      eligible
# 6       eligible      eligible  not eligible      eligible      eligible
# 7       eligible  not eligible  not eligible      eligible      eligible
# 8       eligible  not eligible  not eligible      eligible  not eligible
# 9       eligible      eligible      eligible      eligible      eligible
# 10      eligible      eligible  not eligible      eligible      eligible
# 11  not eligible      eligible      eligible  not eligible  not eligible
# ...

# %%
bonus_func([12,23,56])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-e2f238f8c68a> in <module>()
# ----> 1 bonus_func([12,23,56])
#
# <ipython-input-88-855723ccffa0> in bonus_func(sales_col)
#       1 import numpy as np
#       2 def bonus_func(sales_col):
# ----> 3     elig_values=np.where(sales_col>10,"eligible","not eligible")
#       4     return elig_values
#       5 #store_sales["Jan_bonus"]=bonus_func(store_sales["Jan"])
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
store_sales.iloc[:,2:].apply(bonus_func).head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-90-4ab119a901ac> in <module>()
# ----> 1 store_sales.iloc[:,2:].apply(bonus_func).head()
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4260                         f, axis,
#    4261                         reduce=reduce,
# -> 4262                         ignore_failures=ignore_failures)
#    4263             else:
#    4264                 return self._apply_broadcast(f, axis)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4356             try:
#    4357                 for i, v in enumerate(series_gen):
# -> 4358                     results[i] = func(v)
#    4359                     keys.append(v.name)
#    4360             except Exception as e:
#
# ...

# %%
store_sales.iloc[:,2:].apply(lambda sales_numbers: ["Eligible" if x > 15 else "Not Eligible" for x in sales_numbers]).head()

# %%
store_sales.columns
# Out:
# Index(['store_id', 'city', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'July',
#        'Aug', 'Sep', 'Oct', 'Nov', 'Dec', 'Jan_bonus'],
#       dtype='object')

# %%
store_sales.groupby("city").agg("mean")
# Out:
#                   Jan        Feb        Mar        Apr        May        Jun  \
# city
# Arizona     15.500000  15.272727  14.545455  14.954545  14.090909  15.090909
# California  14.744186  15.534884  14.627907  13.976744  13.255814  13.697674
# Texas       13.457143  14.428571  14.485714  15.057143  13.600000  13.114286
#
#                  July        Aug        Sep        Oct        Nov        Dec
# city
# Arizona     14.636364  15.500000  15.318182  14.954545  16.409091  13.318182
# California  14.813953  16.232558  14.883721  14.279070  15.279070  13.604651
# Texas       13.685714  15.485714  14.685714  13.342857  14.657143  13.685714

# %% [markdown]
# ### Assignments
#
# 1) Find mean quarterly sales by store
#
# 2) Find the month with highest sales for each store

# %% [markdown]
# ## Other/Miscellaneous topics

# %% [markdown]
# ### Missing value treatment

# %%
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# miles_cat        0
# new              0
# dtype: int64

# %%
## Count missing values
df.isnull().sum()
# Out:
# START_DATE*      0
# END_DATE*        0
# CATEGORY*        0
# START*           0
# STOP*            0
# MILES*           0
# PURPOSE*       502
# miles_cat        0
# new              0
# dtype: int64

# %%
# Fill NA with most common values
df["PURPOSE*"].value_counts()
# Out:
# Meeting            187
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE*, dtype: int64

# %%
df = df.fillna({"PURPOSE*":"Meeting"})

# %%
df["PURPOSE*"].value_counts()
# Out:
# Meeting            689
# Meal/Entertain     160
# Errand/Supplies    128
# Customer Visit     101
# Temporary Site      50
# Between Offices     18
# Moving               4
# Airport/Travel       3
# Charity ($)          1
# Commute              1
# Name: PURPOSE*, dtype: int64

# %% [markdown]
# ### Matrix operations use case

# %% [markdown]
# ### Example 1 - compute month on month growth in sales

# %%
store_sales.head()
# Out:
#   store_id        city  Jan  Feb  Mar  Apr  May  Jun  July  Aug  Sep  Oct  \
# 0      S_1       Texas    8   20   13   21   17   20    24   17   16    9
# 1      S_2  California   12   19   15   15   11   19     7   15   10   11
# 2      S_3  California   16   16   14   19   23    6    13   13   15   14
# 3      S_4       Texas    8   18   13   10   14   14     6    8    8   18
# 4      S_5       Texas   19    5   24    9    5   24    10    5   24   15
#
#    Nov  Dec     Jan_bonus
# 0    7    6  not eligible
# 1   21   19      eligible
# 2   24    8      eligible
# 3    7   11  not eligible
# 4    6   13      eligible

# %%
sales_mat = np.array(store_sales.iloc[:,2:])

# %%
sales_mat
# Out:
# array([[8, 20, 13, ..., 7, 6, 'not eligible'],
#        [12, 19, 15, ..., 21, 19, 'eligible'],
#        [16, 16, 14, ..., 24, 8, 'eligible'],
#        ...,
#        [16, 9, 6, ..., 17, 22, 'eligible'],
#        [18, 16, 9, ..., 19, 10, 'eligible'],
#        [5, 23, 17, ..., 5, 9, 'not eligible']], dtype=object)

# %%
sales_mat_lag = sales_mat[:,1:]
sales_mat_lag
# Out:
# array([[20, 13, 21, ..., 7, 6, 'not eligible'],
#        [19, 15, 15, ..., 21, 19, 'eligible'],
#        [16, 14, 19, ..., 24, 8, 'eligible'],
#        ...,
#        [9, 6, 14, ..., 17, 22, 'eligible'],
#        [16, 9, 5, ..., 19, 10, 'eligible'],
#        [23, 17, 24, ..., 5, 9, 'not eligible']], dtype=object)

# %%
sales_mat_lag = sales_mat[:,1:]
sales_mat_lag = np.c_[sales_mat_lag,np.zeros(100)]

# %%
sales_diff = sales_mat_lag - sales_mat
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-103-145f48acb4e5> in <module>()
# ----> 1 sales_diff = sales_mat_lag - sales_mat
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
perct_change = pd.DataFrame(sales_diff/sales_mat)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-104-78bf07865e98> in <module>()
# ----> 1 perct_change = pd.DataFrame(sales_diff/sales_mat)
#
# NameError: name 'sales_diff' is not defined

# %%
perct_change.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-105-9fa81ddfed9c> in <module>()
# ----> 1 perct_change.head()
#
# NameError: name 'perct_change' is not defined

# %% [markdown]
# ### Example 1 - compute net revenue

# %%
profit_mat = np.random.uniform(low=0.05, high=0.25, size=(100,12))

# %%
## Find total annual profit for each store
profit_mat = profit_mat.transpose()

# %%
profit_mat.shape
# Out:
# (12, 100)

# %%
prof_matrix = np.dot(sales_mat,profit_mat)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-844ca2e42343> in <module>()
# ----> 1 prof_matrix = np.dot(sales_mat,profit_mat)
#
# ValueError: shapes (100,13) and (12,100) not aligned: 13 (dim 1) != 12 (dim 0)

# %%
prof_matrix.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-110-52af7535367c> in <module>()
# ----> 1 prof_matrix.shape
#
# NameError: name 'prof_matrix' is not defined
